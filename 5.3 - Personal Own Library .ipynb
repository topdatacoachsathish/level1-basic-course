# %% [markdown]
# # Here's a step-by-step guide to create a dedicated Python library and use it in your main program

# %% [markdown]
# # 1. Create the library directory and file:
#
# Create a new directory to house your library, for example, **my_library**.
#
#
# Inside this directory, create a Python file for your library, such as **my_library.py**

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# ### 2. Define functions in your library file:
#
# In my_library.py, write the functions you want to include in your library:

# %%
def greet(name):
    return "Hello, " + name + "!"

def calculate_area(length, width):
    return length * width

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# ###  3. Import and use your library in your main program:
#
# In your main Python program, import the library

# %% [raw]
# import my_library
#
#
# name = input("Enter your name: ")
# greeting = my_library.greet(name)
# print(greeting)

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [raw]
# #
#
#
# C:\Users\sathishkumar\OneDrive\2_Sat_Learn\01-Python\my_library> python
# Python 3.11.3 (tags/v3.11.3:f3909b8, Apr  4 2023, 23:49:59) [MSC v.1934 64 bit (AMD64)] on win32
# Type "help", "copyright", "credits" or "license" for more information.
# >>> import my_library
# >>> name = input("Enter your name: ")
# Enter your name: Robot
# >>> greeting = my_library.greet(name)
# >>> print(greeting)
# Hello, Robot!
# >>>
